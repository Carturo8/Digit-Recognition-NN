# %%
# Step 1: Import the necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %%
# Step 2: Load the MNIST dataset (already included in Keras)
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Step 3: Normalize the images (from 0–255 to 0–1)
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
# Step 4: Create the neural network model (simple and sequential)
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),     # Converts 28x28 pixels into a 784-length vector
    layers.Dense(128, activation='relu'),     # Hidden layer with 128 neurons and ReLU activation
    layers.Dense(10, activation='softmax')    # Output layer with 10 classes (digits 0–9)
])

# %%
# Step 5: Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Step 6: Train the model
model.fit(x_train, y_train, epochs=5, validation_split=0.1)
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8682 - loss: 0.4599 - val_accuracy: 0.9690 - val_loss: 0.1177
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9641 - loss: 0.1234 - val_accuracy: 0.9695 - val_loss: 0.1029
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9746 - loss: 0.0840 - val_accuracy: 0.9740 - val_loss: 0.0867
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9828 - loss: 0.0567 - val_accuracy: 0.9763 - val_loss: 0.0817
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9867 - loss: 0.0434 - val_accuracy: 0.9790 - val_loss: 0.0761

# %%
# Step 7: Evaluate the model with the test dataset
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'\nTest accuracy: {test_acc:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9742 - loss: 0.0888
#
# Test accuracy: 0.9769

# %%
# Step 8: Make predictions and display some images
predictions = model.predict(x_test)

# Show 5 prediction examples
for i in range(5):
    plt.imshow(x_test[i], cmap='gray')
    plt.title(f'Prediction: {predictions[i].argmax()}, True label: {y_test[i]}')
    plt.axis('off')
    plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
